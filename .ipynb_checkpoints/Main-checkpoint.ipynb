# %% [markdown]
# This code was written for running in Julia

# %%
Δ_SC = 1.0
Δ_Z = 1.1*Δ_SC

θ = pi/4

Δ_I(β) = Δ_SC - Δ_Z*sin(β)
Δ_II(β) = Δ_SC - Δ_Z*cos(β)
Δ_III(β) = Δ_SC - Δ_Z*cos(abs(β - θ))
# Out:
# Δ_III (generic function with 1 method)

# %%
MZM_at_corner1(β) =  (Δ_I(β) > 0 && Δ_II(β) < 0) || (Δ_I(β) < 0 && Δ_II(β) > 0) ? true : false
MZM_at_corner2(β) =  (Δ_III(β) > 0 && Δ_I(β) < 0) || (Δ_III(β) < 0 && Δ_I(β) > 0) ? true : false
MZM_at_corner3(β) =  (Δ_II(β) > 0 && Δ_III(β) < 0) || (Δ_II(β) < 0 && Δ_III(β) > 0) ? true : false
# Out:
# MZM_at_corner3 (generic function with 1 method)

# %%
β = pi/4

@show Δ_I(β) 
@show Δ_II(β) 
@show Δ_III(β)

@show MZM_at_corner1(β)
@show MZM_at_corner2(β)
@show MZM_at_corner3(β)
# Out:
# Δ_I(β) = 0.2221825406947977
# Δ_II(β) = 0.2221825406947976
# Δ_III(β) = -0.10000000000000009
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# true

# %%
β_values = LinRange(0, pi/2, 100)

for β = β_values
    @show Δ_I(β) 
    @show Δ_II(β) 
    @show Δ_III(β)
    
    @show MZM_at_corner1(β)
    @show MZM_at_corner2(β)
    @show MZM_at_corner3(β)
end
# Out:
# Δ_I(β) = 1.0
# Δ_II(β) = -0.10000000000000009
# Δ_III(β) = 0.2221825406947976
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.9825474397817113
# Δ_II(β) = -0.09986154044126261
# Δ_III(β) = 0.20993962270828248
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.9650992731521256
# Δ_II(β) = -0.09944619662150367
# Δ_III(β) = 0.1978955981967051
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.9476598925938835
# Δ_II(β) = -0.09875407310130879
# Δ_III(β) = 0.18605349917882763
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.9302336883777791
# Δ_II(β) = -0.09778534411907303
# Δ_III(β) = 0.17441630683974962
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.9128250474575327
# Δ_II(β) = -0.09654025354713669
# Δ_III(β) = 0.16298695078040937
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.895438352365399
# Δ_II(β) = -0.09501911483039316
# Δ_III(β) = 0.1517683082800736
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.8780779801088879
# Δ_II(β) = -0.09322231090737954
# Δ_III(β) = 0.14076320357199712
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.8607483010688758
# Δ_II(β) = -0.09115029411387487
# Δ_III(β) = 0.1299744071324379
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.8434536778993863
# Δ_II(β) = -0.08880358606902594
# Δ_III(β) = 0.11940463498320353
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.8261984644293151
# Δ_II(β) = -0.0861827775440338
# Δ_III(β) = 0.1090565480079082
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.8089870045663766
# Δ_II(β) = -0.08328852831342881
# Δ_III(β) = 0.09893275128210899
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.7918236312035488
# Δ_II(β) = -0.08012156698897743
# Δ_III(β) = 0.08903579341749202
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.7747126651282903
# Δ_II(β) = -0.07668269083625678
# Δ_III(β) = 0.07936816592027329
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.7576584139348053
# Δ_II(β) = -0.07297276557394783
# Δ_III(β) = 0.0699323025639752
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.74066517093963
# Δ_II(β) = -0.06899272515589594
# Δ_III(β) = 0.06073057877673693
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.7237372141008128
# Δ_II(β) = -0.06474357153599186
# Δ_III(β) = 0.05176531104331372
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.7068788049409616
# Δ_II(β) = -0.06022637441593637
# Δ_III(β) = 0.0430387563219129
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.6900941874744273
# Δ_II(β) = -0.05544227097594723
# Δ_III(β) = 0.034553111476018694
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.6733875871388977
# Δ_II(β) = -0.05039246558848132
# Δ_III(β) = 0.026310512721341772
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.6567632097316642
# Δ_II(β) = -0.045078229515040036
# Δ_III(β) = 0.018313035088038943
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.6402252403508362
# Δ_II(β) = -0.03950090058613531
# Δ_III(β) = 0.010562691898336474
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.6237778423417644
# Δ_II(β) = -0.03366188286449945
# Δ_III(β) = 0.0030614342596849697
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.607425156248941
# Δ_II(β) = -0.02756264629161742
# Δ_III(β) = -0.004188849426419727
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = 0.5911712987736397
# Δ_II(β) = -0.02120472631768
# Δ_III(β) = -0.01118633393983215
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = 0.5750203617375584
# Δ_II(β) = -0.014589723515039621
# Δ_III(β) = -0.017929257701247314
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = 0.5589764110527249
# Δ_II(β) = -0.007719303175276693
# Δ_III(β) = -0.024415923215667323
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = 0.5430434856979249
# Δ_II(β) = -0.0005951948899702852
# Δ_III(β) = -0.03064469749973786
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = 0.5272255967019113
# Δ_II(β) = 0.0067808078847164666
# Δ_III(β) = -0.03661401249284357
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.5115267261336485
# Δ_II(β) = 0.014406848279530426
# Δ_III(β) = -0.042322365451856525
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.49595082609984853
# Δ_II(β) = 0.022281006479584087
# Δ_III(β) = -0.047768319329446696
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.48050181775004897
# Δ_II(β) = 0.03040130020765963
# Δ_III(β) = -0.05295050313584859
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.4651835902894844
# Δ_II(β) = 0.038765685223236535
# Δ_III(β) = -0.05786761228400228
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.45000000000000007
# Δ_II(β) = 0.047372055837117344
# Δ_III(β) = -0.06251840891797533
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.434954869269253
# Δ_II(β) = 0.056218245441525205
# Δ_III(β) = -0.06690172222458579
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.42005198562844737
# Δ_II(β) = 0.06530202705553412
# Δ_III(β) = -0.07101644872815016
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.4052951007988427
# Δ_II(β) = 0.07462111388570059
# Δ_III(β) = -0.07486155256827565
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.3906879297472786
# Δ_II(β) = 0.08417315990175156
# Δ_III(β) = -0.07843606576063267
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.37623414975095215
# Δ_II(β) = 0.0939557604271839
# Δ_III(β) = -0.08173908844064148
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.361937399471682
# Δ_II(β) = 0.10396645274463068
# Δ_III(β) = -0.08476978909000543
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.34780127803989547
# Δ_II(β) = 0.11420271671583548
# Δ_III(β) = -0.08752740474604348
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.3338293441485666
# Δ_II(β) = 0.12466197541608459
# Δ_III(β) = -0.09001124119376169
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.32002511515733423
# Δ_II(β) = 0.1353415957829337
# Δ_III(β) = -0.09222067314061722
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.3063920662070252
# Δ_II(β) = 0.14623888927906747
# Δ_III(β) = -0.09415514437393258
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.2929336293448067
# Δ_II(β) = 0.15735111256912415
# Δ_III(β) = -0.09581416790092012
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.2796531926601864
# Δ_II(β) = 0.16867546821031576
# Δ_III(β) = -0.09719732607127884
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.2665540994320792
# Δ_II(β) = 0.18020910535666967
# Δ_III(β) = -0.09830427068233649
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.2536396472871545
# Δ_II(β) = 0.1919491204767133
# Δ_III(β) = -0.09913472306670634
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.24091308736967687
# Δ_II(β) = 0.20389255808442275
# Δ_III(β) = -0.09968847416244198
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.22837762352304658
# Δ_II(β) = 0.2160364114832507
# Δ_III(β) = -0.0999653845656665
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.2160364114832507
# Δ_II(β) = 0.22837762352304658
# Δ_III(β) = -0.0999653845656665
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.20389255808442275
# Δ_II(β) = 0.24091308736967665
# Δ_III(β) = -0.09968847416244198
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.1919491204767133
# Δ_II(β) = 0.2536396472871545
# Δ_III(β) = -0.09913472306670634
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.18020910535666979
# Δ_II(β) = 0.2665540994320792
# Δ_III(β) = -0.09830427068233649
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.16867546821031587
# Δ_II(β) = 0.2796531926601863
# Δ_III(β) = -0.09719732607127884
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.15735111256912415
# Δ_II(β) = 0.2929336293448066
# Δ_III(β) = -0.09581416790092012
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.14623888927906747
# Δ_II(β) = 0.3063920662070252
# Δ_III(β) = -0.09415514437393258
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.1353415957829337
# Δ_II(β) = 0.32002511515733423
# Δ_III(β) = -0.09222067314061722
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.12466197541608459
# Δ_II(β) = 0.3338293441485666
# Δ_III(β) = -0.09001124119376169
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.1142027167158356
# Δ_II(β) = 0.34780127803989525
# Δ_III(β) = -0.08752740474604348
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.10396645274463068
# Δ_II(β) = 0.361937399471682
# Δ_III(β) = -0.08476978909000543
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.0939557604271839
# Δ_II(β) = 0.37623414975095215
# Δ_III(β) = -0.08173908844064148
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.08417315990175134
# Δ_II(β) = 0.3906879297472786
# Δ_III(β) = -0.07843606576063267
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.0746211138857007
# Δ_II(β) = 0.40529510079884257
# Δ_III(β) = -0.07486155256827565
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.06530202705553412
# Δ_II(β) = 0.42005198562844737
# Δ_III(β) = -0.07101644872815016
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.056218245441525316
# Δ_II(β) = 0.43495486926925286
# Δ_III(β) = -0.06690172222458579
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.047372055837117455
# Δ_II(β) = 0.44999999999999984
# Δ_III(β) = -0.06251840891797533
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.038765685223236535
# Δ_II(β) = 0.4651835902894844
# Δ_III(β) = -0.05786761228400228
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.03040130020765963
# Δ_II(β) = 0.48050181775004897
# Δ_III(β) = -0.05295050313584859
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.022281006479584087
# Δ_II(β) = 0.4959508260998484
# Δ_III(β) = -0.047768319329446696
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.014406848279530426
# Δ_II(β) = 0.5115267261336482
# Δ_III(β) = -0.04232236545185675
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = 0.006780807884716578
# Δ_II(β) = 0.527225596701911
# Δ_III(β) = -0.03661401249284357
# MZM_at_corner1(β) = false
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = true
# Δ_I(β) = -0.0005951948899702852
# Δ_II(β) = 0.5430434856979249
# Δ_III(β) = -0.03064469749973786
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = -0.007719303175276693
# Δ_II(β) = 0.5589764110527249
# Δ_III(β) = -0.024415923215667323
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = -0.014589723515039621
# Δ_II(β) = 0.5750203617375585
# Δ_III(β) = -0.017929257701247314
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = -0.02120472631768
# Δ_II(β) = 0.5911712987736397
# Δ_III(β) = -0.01118633393983215
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = -0.02756264629161742
# Δ_II(β) = 0.6074251562489409
# Δ_III(β) = -0.004188849426419727
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = false
# MZM_at_corner3(β) = true
# Δ_I(β) = -0.033661882864499226
# Δ_II(β) = 0.6237778423417643
# Δ_III(β) = 0.0030614342596849697
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.03950090058613531
# Δ_II(β) = 0.640225240350836
# Δ_III(β) = 0.010562691898336363
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.045078229515040036
# Δ_II(β) = 0.6567632097316641
# Δ_III(β) = 0.018313035088039165
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.05039246558848132
# Δ_II(β) = 0.6733875871388976
# Δ_III(β) = 0.026310512721341772
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.05544227097594723
# Δ_II(β) = 0.6900941874744274
# Δ_III(β) = 0.034553111476018805
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.06022637441593637
# Δ_II(β) = 0.7068788049409616
# Δ_III(β) = 0.04303875632191312
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.06474357153599186
# Δ_II(β) = 0.7237372141008128
# Δ_III(β) = 0.05176531104331372
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.06899272515589594
# Δ_II(β) = 0.7406651709396299
# Δ_III(β) = 0.06073057877673693
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.07297276557394783
# Δ_II(β) = 0.7576584139348052
# Δ_III(β) = 0.06993230256397509
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.07668269083625678
# Δ_II(β) = 0.7747126651282903
# Δ_III(β) = 0.0793681659202734
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.08012156698897743
# Δ_II(β) = 0.7918236312035487
# Δ_III(β) = 0.08903579341749202
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.08328852831342881
# Δ_II(β) = 0.8089870045663765
# Δ_III(β) = 0.09893275128210899
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.0861827775440338
# Δ_II(β) = 0.826198464429315
# Δ_III(β) = 0.1090565480079081
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.08880358606902594
# Δ_II(β) = 0.8434536778993861
# Δ_III(β) = 0.1194046349832033
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09115029411387487
# Δ_II(β) = 0.8607483010688758
# Δ_III(β) = 0.1299744071324379
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09322231090737954
# Δ_II(β) = 0.8780779801088878
# Δ_III(β) = 0.14076320357199712
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09501911483039316
# Δ_II(β) = 0.8954383523653991
# Δ_III(β) = 0.1517683082800737
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09654025354713669
# Δ_II(β) = 0.9128250474575327
# Δ_III(β) = 0.16298695078040948
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09778534411907303
# Δ_II(β) = 0.930233688377779
# Δ_III(β) = 0.17441630683974962
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09875407310130879
# Δ_II(β) = 0.9476598925938834
# Δ_III(β) = 0.18605349917882763
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09944619662150367
# Δ_II(β) = 0.9650992731521254
# Δ_III(β) = 0.197895598196705
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.09986154044126261
# Δ_II(β) = 0.9825474397817113
# Δ_III(β) = 0.2099396227082826
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false
# Δ_I(β) = -0.10000000000000009
# Δ_II(β) = 0.9999999999999999
# Δ_III(β) = 0.2221825406947976
# MZM_at_corner1(β) = true
# MZM_at_corner2(β) = true
# MZM_at_corner3(β) = false

# %% [markdown]
# We can plot this

# %%
using Plots
using LaTeXStrings

# %%
plot(size = (500,500))
plot!(Shape([0,5,5,0], [0, 0, 5, 5]), label = false, color = "gainsboro") #TI
plot!(Shape([5, 5, 3], [0, 2, 0]), color = "lightgoldenrod")
plot!(Shape([0, 0, 2], [5, 3, 5]), color = "lightgoldenrod")

scatter!([5, 0],[0, 5], label = "corner 1", markersize = 10, color = "orange")
scatter!([5, 0],[2, 3], label = "corner 2", markersize = 10, color = "green")
scatter!([3, 2],[0, 5], label = "corner 3", markersize = 10, color = "purple")

x = [0, cos(β)]
y = [0, sin(β)]
plot!(x,y, arrow=(:closed, 5.0), color = "black", linewidth = 1.0, label = "B", xaxis=false, yaxis=false, legend=false, grid = false)
annotate!([2.5], [2.5], "SC")
annotate!([4.5], [0.5], "TI")
annotate!([0.5], [4.5], "TI")


arcx = [cos(theta)/2 for theta = 0:0.01:β]
arcy = [sin(theta)/2 for theta = 0:0.01:β]

plot!(arcx, arcy, linestyle =  :dash, color = "black")
annotate!([0.75], [0.25], L"\beta")
annotate!([cos(β)+0.2], [sin(β)+0.2], L"\vec{B}")

savefig("Setup.pdf")
# Out:
# "C:\\Users\\JOP204\\Documents\\GitHub\\QT_Majorana_Corner_States\\Setup.pdf"

# %%
β_values = LinRange(0, pi/2, 20)

for β = β_values

    theta = round(β*180/pi; digits = 2)

    plot(size = (500,500))
    plot!(Shape([0,5,5,0], [0, 0, 5, 5]), label = false, color = "gainsboro") #TI
    plot!(Shape([5, 5, 3], [0, 2, 0]), color = "lightgoldenrod")
    plot!(Shape([0, 0, 2], [5, 3, 5]), color = "lightgoldenrod")
    
    # @show Δ_I(β) 
    # @show Δ_II(β) 
    # @show Δ_III(β)
    
    # MZM_at_corner1(β) ? scatter!([5, 0],[0, 5], label = false, markersize = 10, color = "orange") : nothing
    # MZM_at_corner2(β) ? scatter!([5, 0],[2, 3], label = false, markersize = 10, color = "green") : nothing
    # MZM_at_corner3(β) ? scatter!([3, 2],[0, 5], label = false, markersize = 10, color = "purple") : nothing

    MZM_at_corner1(β) ? scatter!([5, 0],[0, 5], label = false, markersize = 10, color = "red") : nothing
    MZM_at_corner2(β) ? scatter!([5, 0],[2, 3], label = false, markersize = 10, color = "red") : nothing
    MZM_at_corner3(β) ? scatter!([3, 2],[0, 5], label = false, markersize = 10, color = "red") : nothing    

    x = [0, cos(β)]
    y = [0, sin(β)]
    plot!(x,y, arrow=(:closed, 2.0), color = "black", linewidth = 2.0, label = "B", xaxis=false, yaxis=false, legend=false, grid = false, title = L"\beta ="*"$theta °")    
    annotate!([2.5], [2.5], "SC")
    annotate!([4.5], [0.5], "TI")
    annotate!([0.5], [4.5], "TI")    

    # savefig("Results/β = $theta.pdf")
    savefig("β = $theta.pdf")
end
